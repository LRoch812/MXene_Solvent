# %%
import pandas as pd

# %% [markdown]
# Run below to connect to drive in colab environment

# %%
# Mount google drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Mount google drive
# ----> 2 from google.colab import drive
#       3 drive.mount("/content/drive")
#
# ModuleNotFoundError: No module named 'google'

# %%
# Path of directory
drive_path = "/content/drive/MyDrive"
root_path = f"{drive_path}/master/code-data/mxene_solvent"
solvent_path = f"{drive_path}/master/code-data/solvent"

# %%
# Load data
df_mx_solvent_data_labeled = pd.read_pickle(f"{root_path}/008_dataset_mx_solvent_using_hsp.pkl")
df_mx_solvent_data_labeled.columns = df_mx_solvent_data_labeled.columns.str.lower()
print(df_mx_solvent_data_labeled.shape)
df_mx_solvent_data_labeled.head()
# Out:
# (653, 63)
#       mx method       solvent  label                     inchikey    δd    δp  \
# 0  Ti3C2     HF         water      1  XLYOFNOQVPJJNP-UHFFFAOYSA-N  15.5  16.0
# 1  Ti3C2     HF       ethanol      1  LFQSCWFLJHTTHZ-UHFFFAOYSA-N  15.8   8.8
# 2  Ti3C2     HF      methanol     -1  OKKJLVBELUTLKV-UHFFFAOYSA-N  15.1  12.3
# 3  Ti3C2     HF       acetone     -1  CSCPPACGZOOCGX-UHFFFAOYSA-N  15.5  10.4
# 4  Ti3C2     HF  acetonitrile     -1  WEVYAHXRMPXWCK-UHFFFAOYSA-N  15.3  18.0
#
#      δh  molarvolume  gap_oh  ...  h_bond_donor_count  h_bond_acceptor_count  \
# 0  42.3         18.0     0.0  ...                   1                      1
# 1  19.4         58.5     0.0  ...                   1                      1
# 2  22.3         40.7     0.0  ...                   1                      1
# 3   7.0         74.0     0.0  ...                   0                      1
# 4   6.1         52.6     0.0  ...                   0                      1
#
#    rotatable_bond_count  heavy_atom_count  isotope_atom_count  \
# 0                     0                 1                   0
# 1                     0                 3                   0
# 2                     0                 2                   0
# 3                     0                 4                   0
# 4                     0                 3                   0
#
#    atom_stereo_count  bond_stereo_count  covalent_unit_count  boiling_point  \
# 0                  0                  0                    1          373.2
# 1                  0                  0                    1          351.5
# 2                  0                  0                    1          337.8
# 3                  0                  0                    1          329.3
# 4                  0                  0                    1          354.8
#
#     mmhg
# 0  760.0
# 1  760.0
# 2  760.0
# 3  760.0
# 4  760.0
#
# [5 rows x 63 columns]

# %% [markdown]
# Else run the below to use in local environment

# %%
root_path = f"../../data"

# %%
# Load data
df_mx_solvent_data_labeled = pd.read_excel(f"{root_path}/dataset_mx_solvent_using_hsp.xlsx")
df_mx_solvent_data_labeled.columns = df_mx_solvent_data_labeled.columns.str.lower()
print(df_mx_solvent_data_labeled.shape)
df_mx_solvent_data_labeled.head()
# Out:
# (653, 64)
#    unnamed: 0     mx method       solvent  label                     inchikey  \
# 0           0  Ti3C2     HF         water      1  XLYOFNOQVPJJNP-UHFFFAOYSA-N
# 1           1  Ti3C2     HF       ethanol      1  LFQSCWFLJHTTHZ-UHFFFAOYSA-N
# 2           2  Ti3C2     HF      methanol     -1  OKKJLVBELUTLKV-UHFFFAOYSA-N
# 3           3  Ti3C2     HF       acetone     -1  CSCPPACGZOOCGX-UHFFFAOYSA-N
# 4           4  Ti3C2     HF  acetonitrile     -1  WEVYAHXRMPXWCK-UHFFFAOYSA-N
#
#      δd    δp    δh  molarvolume  ...  h_bond_donor_count  \
# 0  15.5  16.0  42.3         18.0  ...                   1
# 1  15.8   8.8  19.4         58.5  ...                   1
# 2  15.1  12.3  22.3         40.7  ...                   1
# 3  15.5  10.4   7.0         74.0  ...                   0
# 4  15.3  18.0   6.1         52.6  ...                   0
#
#    h_bond_acceptor_count  rotatable_bond_count  heavy_atom_count  \
# 0                      1                     0                 1
# 1                      1                     0                 3
# 2                      1                     0                 2
# 3                      1                     0                 4
# 4                      1                     0                 3
#
#    isotope_atom_count  atom_stereo_count  bond_stereo_count  \
# 0                   0                  0                  0
# 1                   0                  0                  0
# 2                   0                  0                  0
# 3                   0                  0                  0
# 4                   0                  0                  0
#
#    covalent_unit_count  boiling_point  mmhg
# 0                    1          373.2   760
# 1                    1          351.5   760
# 2                    1          337.8   760
# 3                    1          329.3   760
# 4                    1          354.8   760
#
# [5 rows x 64 columns]

# %% [markdown]
# Main body of code

# %%
cols_to_keep = [col for col in df_mx_solvent_data_labeled.columns if not (df_mx_solvent_data_labeled[col].nunique() <= 1)]

# %%
df_mx_solvent_data_labeled = df_mx_solvent_data_labeled[cols_to_keep]

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.svm import SVC

# %%
df_mx_solvent_data_labeled['method'] = df_mx_solvent_data_labeled['method'].astype('category').cat.codes

# %%
df_mx_solvent_data_labeled.head()
# Out:
#    unnamed: 0     mx  method       solvent  label  \
# 0           0  Ti3C2       0         water      1
# 1           1  Ti3C2       0       ethanol      1
# 2           2  Ti3C2       0      methanol     -1
# 3           3  Ti3C2       0       acetone     -1
# 4           4  Ti3C2       0  acetonitrile     -1
#
#                       inchikey    δd    δp    δh  molarvolume  ...  \
# 0  XLYOFNOQVPJJNP-UHFFFAOYSA-N  15.5  16.0  42.3         18.0  ...
# 1  LFQSCWFLJHTTHZ-UHFFFAOYSA-N  15.8   8.8  19.4         58.5  ...
# 2  OKKJLVBELUTLKV-UHFFFAOYSA-N  15.1  12.3  22.3         40.7  ...
# 3  CSCPPACGZOOCGX-UHFFFAOYSA-N  15.5  10.4   7.0         74.0  ...
# 4  WEVYAHXRMPXWCK-UHFFFAOYSA-N  15.3  18.0   6.1         52.6  ...
#
#    molecular_weight  xlogp  tpsa  complexity  h_bond_donor_count  \
# 0            18.015   -0.5   1.0         0.0                   1
# 1            46.070   -0.1  20.2         2.8                   1
# 2            32.042   -0.5  20.2         2.0                   1
# 3            58.080   -0.1  17.1        26.3                   0
# 4            41.050    0.0  23.8        29.3                   0
#
#    h_bond_acceptor_count  rotatable_bond_count  heavy_atom_count  \
# 0                      1                     0                 1
# 1                      1                     0                 3
# 2                      1                     0                 2
# 3                      1                     0                 4
# 4                      1                     0                 3
#
#    atom_stereo_count  boiling_point
# 0                  0          373.2
# 1                  0          351.5
# 2                  0          337.8
# 3                  0          329.3
# 4                  0          354.8
#
# [5 rows x 48 columns]

# %%
features = ['method', 'δd', 'δp', 'δh', 'molarvolume', 'work_function_oh',
   'formation_energy_oh', 'ehull_oh', 'alphax_el_oh', 'alphay_el_oh', 'alphaz_el_oh',
   'plasmafrequency_x_oh', 'plasmafrequency_y_oh', 'has_inversion_symmetry_oh',
   'gap_o', 'work_function_o', 'formation_energy_o', 'ehull_o',
   'alphax_el_o', 'alphay_el_o', 'alphaz_el_o', 'plasmafrequency_x_o', 'plasmafrequency_y_o',
    'has_inversion_symmetry_o', 'work_function_f',
   'formation_energy_f', 'ehull_f', 'alphax_el_f', 'alphay_el_f', 'alphaz_el_f', 'plasmafrequency_x_f',
   'plasmafrequency_y_f', 'has_inversion_symmetry_f',
   'molecular_weight', 'xlogp',  'tpsa', 'complexity', 'h_bond_donor_count', 'h_bond_acceptor_count',
   'rotatable_bond_count', 'heavy_atom_count',  'atom_stereo_count',
    'boiling_point']
X = df_mx_solvent_data_labeled[features]
y = df_mx_solvent_data_labeled['label']

# %%
X['molecular_weight'] = pd.to_numeric(X['molecular_weight'], errors='coerce')
# Out:
# C:\Users\liamr\AppData\Local\Temp\ipykernel_7948\2546690500.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['molecular_weight'] = pd.to_numeric(X['molecular_weight'], errors='coerce')

# %%
X.head()
# Out:
#    method    δd    δp    δh  molarvolume  work_function_oh  \
# 0       0  15.5  16.0  42.3         18.0          1.985656
# 1       0  15.8   8.8  19.4         58.5          1.985656
# 2       0  15.1  12.3  22.3         40.7          1.985656
# 3       0  15.5  10.4   7.0         74.0          1.985656
# 4       0  15.3  18.0   6.1         52.6          1.985656
#
#    formation_energy_oh  ehull_oh  alphax_el_oh  alphay_el_oh  ...  \
# 0            -1.294839  0.123329     32.369286     32.369286  ...
# 1            -1.294839  0.123329     32.369286     32.369286  ...
# 2            -1.294839  0.123329     32.369286     32.369286  ...
# 3            -1.294839  0.123329     32.369286     32.369286  ...
# 4            -1.294839  0.123329     32.369286     32.369286  ...
#
#    molecular_weight  xlogp  tpsa  complexity  h_bond_donor_count  \
# 0            18.015   -0.5   1.0         0.0                   1
# 1            46.070   -0.1  20.2         2.8                   1
# 2            32.042   -0.5  20.2         2.0                   1
# 3            58.080   -0.1  17.1        26.3                   0
# 4            41.050    0.0  23.8        29.3                   0
#
#    h_bond_acceptor_count  rotatable_bond_count  heavy_atom_count  \
# 0                      1                     0                 1
# 1                      1                     0                 3
# 2                      1                     0                 2
# 3                      1                     0                 4
# 4                      1                     0                 3
#
#    atom_stereo_count  boiling_point
# 0                  0          373.2
# 1                  0          351.5
# 2                  0          337.8
# 3                  0          329.3
# 4                  0          354.8
#
# [5 rows x 43 columns]

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2   -1
# 3   -1
# 4   -1
# Name: label, dtype: int64

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
mask_pos = y == 1
mask_neg = y == -1
mask_unlabeled = y == 0

# %%
X_train = X_scaled[mask_pos | mask_neg]
y_train = y[mask_pos | mask_neg]

# %%
X_test = X_scaled[mask_unlabeled]
df_unlabeled = df_mx_solvent_data_labeled[mask_unlabeled].copy()

# %%
clf = SVC(kernel='linear', C=1.0, gamma='scale', probability=True)
clf.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %%
proba_unlabeled = clf.predict_proba(X_test)[:, 1]  # Probability of class 1 (positive)
df_unlabeled['predicted_proba'] = proba_unlabeled
df_unlabeled['predicted_label'] = (proba_unlabeled >= 0.5).astype(int)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(proba_unlabeled, bins=30, kde=True)
plt.axvline(0.5, color='red', linestyle='--', label='Threshold = 0.5')
plt.title("Prediction Probabilities on Unlabeled Data")
plt.xlabel("Predicted Probability of Positive Class")
plt.ylabel("Count")
plt.legend()
plt.tight_layout()
plt.show()

# %%
high_conf = df_unlabeled[df_unlabeled['predicted_proba'] >= 0.9]
top_10 = high_conf.sort_values(by='predicted_proba', ascending=False).head(20)
print(top_10[['solvent', 'mx', 'predicted_proba']])
# Out:
#                solvent     mx  predicted_proba
# 285  diethylene glycol  Mo2C1         0.996698
# 286  diethylene glycol  Mo2C1         0.996698
# 128  diethylene glycol  Nb2C1         0.996520
# 129  diethylene glycol  Nb2C1         0.996520
# 206  diethylene glycol   V2C1         0.996472
# 207  diethylene glycol   V2C1         0.996472
# 522  diethylene glycol   V4C3         0.996463
# 523  diethylene glycol   V4C3         0.996463
# 601  diethylene glycol  Ta4C3         0.996444
# 602  diethylene glycol  Ta4C3         0.996444
# 364  diethylene glycol  Ti2C1         0.996384
# 365  diethylene glycol  Ti2C1         0.996384
# 443  diethylene glycol  Zr3C2         0.995753
# 444  diethylene glycol  Zr3C2         0.995753
# 76   diethylene glycol  Ti3C2         0.995753
# 283          formamide  Mo2C1         0.992728
# 284          formamide  Mo2C1         0.992728
# 126          formamide  Nb2C1         0.992338
# 127          formamide  Nb2C1         0.992337
# 204          formamide   V2C1         0.992234

# %%
low_conf = df_unlabeled[df_unlabeled['predicted_proba'] <= 0.1]
bottom_10 = low_conf.sort_values(by='predicted_proba', ascending=True).head(20)

print("MXene-solvent pairs predicted to NOT work at all (P ≤ 0.1):")
print(bottom_10[['mx', 'solvent', 'predicted_proba']])
# Out:
# MXene-solvent pairs predicted to NOT work at all (P ≤ 0.1):
#         mx             solvent  predicted_proba
# 86   Ti3C2  Tetrachloromethane         0.028141
# 464  Zr3C2  Tetrachloromethane         0.028141
# 463  Zr3C2  Tetrachloromethane         0.028142
# 438  Zr3C2            n-Hexane         0.030997
# 437  Zr3C2            n-Hexane         0.030998
# 385  Ti2C1  Tetrachloromethane         0.033024
# 384  Ti2C1  Tetrachloromethane         0.033024
# 622  Ta4C3  Tetrachloromethane         0.033576
# 621  Ta4C3  Tetrachloromethane         0.033577
# 79   Ti3C2     Dichloromethane         0.033722
# 450  Zr3C2     Dichloromethane         0.033723
# 449  Zr3C2     Dichloromethane         0.033724
# 543   V4C3  Tetrachloromethane         0.033757
# 542   V4C3  Tetrachloromethane         0.033758
# 227   V2C1  Tetrachloromethane         0.033846
# 226   V2C1  Tetrachloromethane         0.033847
# 149  Nb2C1  Tetrachloromethane         0.034302
# 148  Nb2C1  Tetrachloromethane         0.034302
# 306  Mo2C1  Tetrachloromethane         0.036138
# 305  Mo2C1  Tetrachloromethane         0.036138

# %%
print("\n=== Summary of predicted probabilities on unlabeled data ===")
print(df_unlabeled['predicted_proba'].describe())

# Count how many samples fall into different confidence zones
bins = [0.0, 0.1, 0.3, 0.5, 0.7, 0.9, 1.0]
labels = ['Very Low (≤0.1)', 'Low (0.1–0.3)', 'Mid (0.3–0.5)',
          'High (0.5–0.7)', 'Very High (0.7–0.9)', 'Extremely High (>0.9)']

df_unlabeled['confidence_bin'] = pd.cut(df_unlabeled['predicted_proba'], bins=bins, labels=labels, include_lowest=True)
print("\n=== Prediction count by confidence bin ===")
print(df_unlabeled['confidence_bin'].value_counts().sort_index())
# Out:
# === Summary of predicted probabilities on unlabeled data ===
# count    579.000000
# mean       0.470673
# std        0.347288
# min        0.028141
# 25%        0.138484
# 50%        0.263952
# 75%        0.781355
# max        0.996698
# Name: predicted_proba, dtype: float64
#
# === Prediction count by confidence bin ===
# confidence_bin
# Very Low (≤0.1)          119
# Low (0.1–0.3)            176
# Mid (0.3–0.5)              0
# High (0.5–0.7)            15
# Very High (0.7–0.9)      224
# Extremely High (>0.9)     45
# Name: count, dtype: int64

# %% [markdown]
# Again, use the below if running in colab

# %%
train_path = f"{drive_path}/master/code-data/training/"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 train_path = f"{drive_path}/master/code-data/training/"
#
# NameError: name 'drive_path' is not defined

# %%
df_unlabeled.to_csv(f"{train_path}/003_positive_vs_negative_predictions_on_unlabeled_svc.csv")
df_unlabeled.to_pickle(f"{train_path}/003_positive_vs_negative_predictions_on_unlabeled_svc.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df_unlabeled.to_csv(f"{train_path}/003_positive_vs_negative_predictions_on_unlabeled_svc.csv")
#       2 df_unlabeled.to_pickle(f"{train_path}/003_positive_vs_negative_predictions_on_unlabeled_svc.pkl")
#
# NameError: name 'train_path' is not defined

# %% [markdown]
# If running locally, use the below

# %%
df_unlabeled.to_csv(f"003_positive_vs_negative_predictions_on_unlabeled_svc.csv")
df_unlabeled.to_pickle(f"003_positive_vs_negative_predictions_on_unlabeled_svc.pkl")

# %% [markdown]
# Main body of code

# %%
feature_names = features
importances = pd.Series(abs(clf.coef_[0]), index=feature_names)

# Create a DataFrame for better visualization
feat_imp_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

print(feat_imp_df)

# Plot
plt.figure(figsize=(8, 5))
sns.barplot(x='Importance', y='Feature', data=feat_imp_df, palette='viridis')
plt.title('Feature Importance from SVC')
plt.tight_layout()
plt.show()
# Out:
#                                              Feature    Importance
# boiling_point                          boiling_point  1.107215e+00
# molarvolume                              molarvolume  8.954978e-01
# tpsa                                            tpsa  7.899856e-01
# xlogp                                          xlogp  5.845287e-01
# δh                                                δh  5.806404e-01
# h_bond_donor_count                h_bond_donor_count  5.305686e-01
# h_bond_acceptor_count          h_bond_acceptor_count  5.159467e-01
# rotatable_bond_count            rotatable_bond_count  4.828778e-01
# molecular_weight                    molecular_weight  3.488536e-01
# heavy_atom_count                    heavy_atom_count  2.951018e-01
# δp                                                δp  1.593238e-01
# complexity                                complexity  5.205349e-02
# δd                                                δd  2.771773e-02
# has_inversion_symmetry_f    has_inversion_symmetry_f  1.465210e-02
# has_inversion_symmetry_oh  has_inversion_symmetry_oh  1.465210e-02
# has_inversion_symmetry_o    has_inversion_symmetry_o  1.465210e-02
# plasmafrequency_y_oh            plasmafrequency_y_oh  7.323219e-03
# plasmafrequency_x_oh            plasmafrequency_x_oh  7.323219e-03
# alphaz_el_f                              alphaz_el_f  6.680810e-03
# alphaz_el_o                              alphaz_el_o  5.872379e-03
# ehull_oh                                    ehull_oh  5.729475e-03
# alphaz_el_oh                            alphaz_el_oh  5.190520e-03
# plasmafrequency_y_f              plasmafrequency_y_f  4.664018e-03
# plasmafrequency_x_f              plasmafrequency_x_f  4.664018e-03
# ehull_f                                      ehull_f  4.529622e-03
# formation_energy_oh              formation_energy_oh  4.450369e-03
# work_function_oh                    work_function_oh  4.024962e-03
# ehull_o                                      ehull_o  2.830104e-03
# gap_o                                          gap_o  2.641607e-03
# plasmafrequency_y_o              plasmafrequency_y_o  1.818674e-03
# plasmafrequency_x_o              plasmafrequency_x_o  1.818674e-03
# alphay_el_o                              alphay_el_o  1.609954e-03
# alphax_el_o                              alphax_el_o  1.609954e-03
# work_function_o                      work_function_o  1.232673e-03
# alphax_el_oh                            alphax_el_oh  1.185730e-03
# alphay_el_oh                            alphay_el_oh  1.185730e-03
# formation_energy_f                formation_energy_f  1.167869e-03
# formation_energy_o                formation_energy_o  1.100405e-03
# work_function_f                      work_function_f  6.280872e-04
# alphax_el_f                              alphax_el_f  2.930853e-04
# alphay_el_f                              alphay_el_f  2.930853e-04
# method                                        method  9.313704e-06
# atom_stereo_count                  atom_stereo_count  5.551115e-17
# C:\Users\liamr\AppData\Local\Temp\ipykernel_7948\1863205878.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feat_imp_df, palette='viridis')

# %%
# Create and sort feature importance DataFrame
feat_imp_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False).head(10)  # Change to .head(15) for top 15

# Print top features
print("Top 10 Feature Importances:")
print(feat_imp_df)

# Plot
plt.figure(figsize=(8, 5))
sns.barplot(x='Importance', y='Feature', data=feat_imp_df, palette='mako')
plt.title('Top 10 Feature Importances from SVC')
plt.tight_layout()
plt.show()
# Out:
# Top 10 Feature Importances:
#                                      Feature  Importance
# boiling_point                  boiling_point    1.107215
# molarvolume                      molarvolume    0.895498
# tpsa                                    tpsa    0.789986
# xlogp                                  xlogp    0.584529
# δh                                        δh    0.580640
# h_bond_donor_count        h_bond_donor_count    0.530569
# h_bond_acceptor_count  h_bond_acceptor_count    0.515947
# rotatable_bond_count    rotatable_bond_count    0.482878
# molecular_weight            molecular_weight    0.348854
# heavy_atom_count            heavy_atom_count    0.295102
# C:\Users\liamr\AppData\Local\Temp\ipykernel_7948\692532943.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feat_imp_df, palette='mako')

# %%
highimpdf = df_mx_solvent_data_labeled[feat_imp_df["Feature"]]
print(highimpdf.describe())

correlation_matrix = highimpdf.corr()
plt.figure(figsize=(25,25))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.tick_params(axis='x', which='major', labelsize=15, labelbottom = False, bottom=False, top = False, labeltop=True, labelrotation=90)
plt.tick_params(axis='y', which='major', labelsize=15, labelrotation=0)
plt.show()
# Out:
#        boiling_point  molarvolume        tpsa       xlogp          δh  \
# count     653.000000   653.000000  653.000000  653.000000  653.000000
# mean      400.388974    92.607351   16.879632    1.093874    9.078254
# std        58.975900    38.511710   15.421328    1.706149    8.276655
# min       313.000000    18.000000    0.000000   -1.300000    0.000000
# 25%       351.500000    71.300000    0.000000   -0.500000    3.300000
# 50%       383.800000    85.000000   20.200000    0.700000    7.200000
# 75%       455.700000   108.600000   21.300000    2.700000   13.900000
# max       519.000000   209.500000   64.200000    4.600000   42.300000
#
#        h_bond_donor_count  h_bond_acceptor_count  rotatable_bond_count  \
# count          653.000000             653.000000            653.000000
# mean             0.349158               0.977029              1.082695
# std              0.525999               0.820234              2.208299
# min              0.000000               0.000000              0.000000
# 25%              0.000000               0.000000              0.000000
# 50%              0.000000               1.000000              0.000000
# 75%              1.000000               1.000000              1.000000
# max              2.000000               3.000000              9.000000
#
#        molecular_weight  heavy_atom_count
# count        653.000000        653.000000
# mean          88.068231          5.578867
# std           33.614616          2.290681
# min           18.015000          1.000000
# 25%           60.100000          4.000000
# 50%           87.120000          6.000000
# 75%          102.090000          7.000000
# max          174.280000         12.000000

# %%
correlation_matrix = df_mx_solvent_data_labeled[features].corr()
plt.figure(figsize=(25,25))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.tick_params(axis='x', which='major', labelsize=15, labelbottom = False, bottom=False, top = False, labeltop=True, labelrotation=90)
plt.tick_params(axis='y', which='major', labelsize=15, labelrotation=0)
plt.show()
